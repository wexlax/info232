# %% [markdown]
# <div>
# <img src="logo.png", width=100, ALIGN="left">
# <center>
# <h1>Mini Projets 2019-2020 (Info 232)</h1>
# Isabelle Guyon <br>
# info232@chalearn.org <br>
# </center>
# <span style="color:red"> <h1> 2 . Pandas </h1> </span>
#
# We have now a dataset of pictures of REAL apples and bananas, preprocessed in 4 different representations:
# - one with only 2 features (<b>R</b>edness and <b>E</b>longation) called <b>RE_data.csv</b>
# - one with only 21 features (<b>C</b>olor and <b>S</b>hape features) called <b>CS_data.csv</b>
# - one with 14580 features (all pixels of 81x69x3 <b>raw</b> images) called <b>RAW_data.csv</b>
# - one with 3072 features (all pixels of 32x32x3 <b>crop</b>ped images) called <b>CROP_data.csv</b>.
#
# We will compare the performances of various classifiers on those 4 datasets. Thus, we are going to start doing "real" POM: Probability, Optimization, and Modeling. We will proceed in a "greedy" way, eliminating some non promising avenues as we go, and not revisiting them for the moment:
#
# 1. Which dataset version should we keep? Should we or not scale variables (using variable standardization)?
# 2. Which learning machine of a standard toolkit (scikit-learn) is most promising?
#
# </div>
# <div style="background:#FFFFAA">
#
#  This TP gives you 5 points if you answer well ALL 5 questions. If you cannot fisnish, get help by attending the Wednesday session.
#
# <span style="color:red"> <b>Save your notebook often with menu File + Save and Checkpoint.</b>
# <br> <b>Before you push your homework to your GitHub repo, use  Kernel + Restart and Run all.</b>
# </span>
#     </div>

# %%
# Load general libraries
import os, re
from glob import glob as ls
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

### Add path to the sample code so the notebook finds it:

code_dir = 'code/'                        
from sys import path; path.append(code_dir)
from utilities import *
# Import code that checks your answers
from checker import check 
# Disable some warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Step 1: Select data representation
# Which dataset version should we keep? Should we do or not a variable standardization?

# %% [markdown]
# ### Question 0: Examine the data directory
# Go to the directory `mini-dataset/`. You should find four data files ending with `.csv`. In an editor, open `RL_data.csv` or another of the data files to see how it looks like. The dataset is formatted in the CSV format (comma separated file). The examples are in lines and the features are separated by commas. The first line is the header.
#
# Examine all 4 datasets and note the number of lines and columns. Notice that they all have a different number of features but the same number of examples.
#
# It is somewhat easier to write a Python program to do this work for you. Check how the function `check_datasets` is written by typing `??check_datasets` in a new cell. Verify with an editor that this is the same code that is found in the directory `code/` in the file `utilities.py`.

# %%
# List the datasets
data_dir = './mini-dataset/'
data_list = ls(data_dir + '*_data.csv')
data_list
# Out:
# ['./mini-dataset/RE_data.csv',
#  './mini-dataset/RAW_data.csv',
#  './mini-dataset/CS_data.csv',
#  './mini-dataset/CROP_data.csv']

# %%
??check_datasets

# %%
# Check the dataset sizes
check_datasets(data_list)
# Out:
#   Dataset  num. examples  num. features  num. apples  num. bananas
# 0      RE            491              3          333           158
# 1     RAW            491          14581          333           158
# 2      CS            491             22          333           158
# 3    CROP            491           3073          333           158

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Show the code of check_datasets.</b>

# %%
def check_datasets(data_list):
    ''' Create a table with dataset statistics.'''
    col = ['Dataset', 'num. examples', 'num. features', 'num. apples', 'num. bananas']
    data = []
    for file in data_list:
        df = pd.read_csv(file)
        N, F = df.shape
        Na = sum(df.iloc[:,-1]==1)
        Nb = sum(df.iloc[:,-1]==-1)
        data.append([os.path.basename(file)[:-9],N,F,Na,Nb])
        stat_df = pd.DataFrame(data, columns = col)
    return stat_df

# %% [markdown]
# ### Question 1: Load and visualize data with Pandas (review)
# In previous classes we have have started using `Numpy arrays`and `Pandas dataframes`. We now explore Pandas a little bit further. Pandas dataframes are also arrays, but a different kind of python object that Numpy arrays. They have more properties, supporting fancy database functions and having quite a few display functions and nice simple summary statistics, <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html">check the documentation</a>. Learning about Pandas will help a lot the <i>visualization binome</i>.
#
# First, you will perform these steps:
# * Call to UNIX command `!head ./mini-dataset/RE_data.csv` to view the first few lines of the file. The character `!` allows you to "escape" from the Jupyter notebook to the UNIX shell.
# * Load `RL_data.csv` as a pandas dataframe called `df`. Show the first few lines using the method `head`.
# * Compute simple statistics using the method `describe`.
# * Show the heat map. If you do not remember from the previous TP, think of using a search engine and type the keywords: "pandas heatmap". I found <a href="https://stackoverflow.com/questions/12286607/making-heatmap-from-pandas-dataframe">this post</a>, for instance.
# * Create a new data frame called `df_scaled` obtained by standardizing the columns of `df`. In the previous TP we used the method `StandardScaler` of `sklearn.preprocessing`. Notice that you can also simply compute the mean of `df` with `df.mean()` and the standard deviation with `df.std()`, then in one line of code get `df_scaled` by performing algebraic operations on dataframes!
# * We actually doe NOT want to standardize the <b>last column</b> (the class label). Make sure the last column of  `df_scaled` has the ORIGINAL label values +1 or -1.
#
# Then, the question you should answer to complete this section is: what are the mean and standard deviation of the lines and the columns of the `redness` and `elongation` features before and after standardization?

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Put here your call to the UNIX command "head".</b>

# %%
# !head -5 mini-dataset/RE_data.csv
# Out:
# redness,elongation,fruit
# 8.429611650485437,1.4032012759326986,1.0
# 42.89607843137255,1.7032009898154288,1.0
# 56.354066985645936,1.5508105645577395,1.0
# -10.528846153846153,1.7773426521360935,1.0

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Read file RE_data.csv as a dataframe and call it "df".</b>

# %%
df = pd.DataFrame(pd.read_csv('mini-dataset/RE_data.csv')) # REPLACE THIS
df.head()
# Out:
#      redness  elongation  fruit
# 0   8.429612    1.403201    1.0
# 1  42.896078    1.703201    1.0
# 2  56.354067    1.550811    1.0
# 3 -10.528846    1.777343    1.0
# 4 -17.131387    2.047174    1.0

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Show descriptive statistics with the method "describe".</b>

# %%
df.describe()
# Out:
#           redness  elongation       fruit
# count  491.000000  491.000000  491.000000
# mean    17.863426    1.468878    0.356415
# std     21.805386    0.521078    0.935280
# min    -47.045455    1.000000   -1.000000
# 25%      3.895620    1.161664   -1.000000
# 50%     14.380952    1.300111    1.000000
# 75%     33.848108    1.598103    1.000000
# max    100.364865    5.231697    1.000000

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Show the heat map of "df".</b>

# %%
fig = plt.figure(figsize=(5,100))
sns.heatmap(df,cmap='RdYlGn', annot=True)

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Standardize the columns of "df", EXCEPT THE LAST ONE.</b>

# %%
import numpy as np 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() 
column_names_to_normalize = ['redness', 'elongation']


df_scaled = pd.DataFrame(pd.read_csv('mini-dataset/RE_data.csv'))
x_scaled=(df[column_names_to_normalize]-df[column_names_to_normalize].mean())/df[column_names_to_normalize].std()
df_scaled[column_names_to_normalize] = x_scaled
df.columns[-1]
# Out:
# 'fruit'

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Your final answers to question 1. </b> What are the mean and standard deviation of the lines and the columns of the `redness` and `elongation` features before and after standardization?

# %%
question = 1
score = 0
# Put your answers to question 1 here
redness_mean_before, elongation_mean_before, label_mean_before = df['redness'].mean(), df['elongation'].mean(), df['fruit'].mean()
redness_std_before, elongation_std_before, label_std_before = df['redness'].std(), df['elongation'].std(),df['fruit'].std()
redness_mean_after, elongation_mean_after, label_mean_after = df_scaled['redness'].mean(), df_scaled['elongation'].mean(), df_scaled['fruit'].mean()
redness_std_after, elongation_std_after, label_std_after = df_scaled['redness'].std(), df_scaled['elongation'].std(), df_scaled['fruit'].std()

# This is the checker code, keep it
answer = redness_mean_before+elongation_mean_before+label_mean_before
answer += redness_std_before+elongation_std_before+label_std_before
answer -= redness_mean_after+elongation_mean_after+label_mean_after
answer -= redness_std_after+elongation_std_after+label_std_after
score += check(answer, question)
# Out:
# 39.65876749424191
# 39.6587674942419
# <div style="background:#00FF00">CORRECT<br>:-)</div>

# %% [markdown]
# ### Question 2: Write a function to standardize data
# It is often useful to `standardize` the columns of the data matrix to put all values in a similar scale, so to facilitate re-using this operation, write a function that takes as input a data frame `df` containing a dataset and returns a dataframe `df_scaled` with the columns standardized <b>EXCEPT THE TARGET VALUES</b> of the last column (use your answers to the previous section). Use this template for your code:
#
#     def standardize_df(df):
#     '''Standardize all the columns except the last one (target values).'''
#     # YOUR CODE HERE
#     return df_scaled
#
# Test your function with the same dataframe as in the previous questions and use the methods `head` and `describe` to verify that all the columns are standardized, except the last one. Notice that, due to machine precision, you may not get exactly mean=0 and std=1.

# %%
# Replace by your own code:
def standardize_df(df):
    '''Standardize all the columns except the last one (target values).'''
    column_names = df.columns[0:len(df.columns)-1]
    last_column = df.columns[-1]
    df_scaled = (df-df.mean())/df.std()
    df_scaled[last_column] = df[last_column]
    print(df_scaled)
    return df_scaled


df_scaled2 = standardize_df(df)
df_scaled2.head()
# Out:
#       redness  elongation  fruit
# 0   -0.432637   -0.126039    1.0
# 1    1.148003    0.449690    1.0
# 2    1.765190    0.157238    1.0
# 3   -1.302076    0.591975    1.0
# 4   -1.604870    1.109809    1.0
# ..        ...         ...    ...
# 486  1.494568    1.002116   -1.0
# 487  0.684247    1.643895   -1.0
# 488  0.188271    2.106111   -1.0
# 489  0.224988    3.117721   -1.0
# 490  0.520381    2.133680   -1.0
#
# [491 rows x 3 columns]
#     redness  elongation  fruit
# 0 -0.432637   -0.126039    1.0
# 1  1.148003    0.449690    1.0
# 2  1.765190    0.157238    1.0
# 3 -1.302076    0.591975    1.0
# 4 -1.604870    1.109809    1.0

# %%
df_scaled2.describe()
# Out:
#             redness    elongation       fruit
# count  4.910000e+02  4.910000e+02  491.000000
# mean  -1.447134e-16 -7.380383e-16    0.356415
# std    1.000000e+00  1.000000e+00    0.935280
# min   -2.976736e+00 -8.998221e-01   -1.000000
# 25%   -6.405668e-01 -5.895726e-01   -1.000000
# 50%   -1.597070e-01 -3.238798e-01    1.000000
# 75%    7.330612e-01  2.479972e-01    1.000000
# max    3.783535e+00  7.221221e+00    1.000000

# %%
# This is the checker code, keep it
question = 2
answer = (df_scaled == df_scaled2).all().all()
score += check(answer, question)
# Out:
# True
# 1
# <div style="background:#00FF00">CORRECT<br>:-)</div>

# %% [markdown]
# ### Question 3: Select the best representation
# We are now going to loop over all datasets and compare the performance of our baseline method (one nearest neighbor classifier) with and without variable scaling.
#
# First you will perform these steps (with some help):
# * Import `KNeighborsClassifier` from the scikit-learn library (`sklearn`) and instanciate a one nearest neighbor classifier that you will call `sklearn_model`. Also import the `balanced_accuracy_score` and name it `sklearn_metric`.
# * Call `df_cross_validate(df, sklearn_model, sklearn_metric)` and collect the results, then print the training and test performance and their error bars. <b>Tip:</b> look at the bottom of the code using `??df_cross_validate` to get an idea on how to print the results.
# * Create:
#  * a list containing all the dataset dataframes and call it `all_data_df`
#  * a list containg all the dataset names and call it `data_name`.
# * Run the function `systematic_data_experiment(data_name, all_scaled_data_df, sklearn_model, sklearn_metric)` and display the results.
# * <b>Create a list</b> containing all the SCALED datasets (variables standardized) and call it `all_scaled_data_df`.
# * Run again `systematic_data_experiment` on `all_scaled_data_df` and display the results.
# * Fuse the results of the two previous question by creating a dataframe called `joint_results`. Assign `result_scaling.perf_te` to a column called `'SCALED'` and `result_noscaling.perf_te` to a column called `'NOT SCALED'`. Display the results.
# * Visualize `joint_results` with a histogram. Check <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.bar.html">this documentation</a>.
#
# Then the questions you should answer are:
# * Does re-scaling variables always help?
# * Is which case does it help most?
#
# Try to reason why this might be.

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Make necessary changes; USE THE DOCUMENTATION OF SCIKIT LEARN (do not copy on your neighbor).</b>

# %%
from sklearn.neighbors import KNeighborsClassifier  # Replace that by nearest neighbors
from sklearn.metrics import balanced_accuracy_score as sklearn_metric # Replace that by balanced accuracy 
sklearn_model = KNeighborsClassifier(n_neighbors=1) # Replace by ONE nearest neighbor

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Collect the results of df_cross_validate(df, sklearn_model, sklearn_metric).</b>

# %%
p_tr, s_tr, p_te, s_te  = df_cross_validate(df, sklearn_model, sklearn_metric) # REPLACE THIS!

metric_name = sklearn_metric.__name__.upper()
print("AVERAGE TRAINING {0:s} +- STD: {1:.2f} +- {2:.2f}".format(metric_name, p_tr, s_tr))
print("AVERAGE TEST {0:s} +- STD: {1:.2f} +- {2:.2f}".format(metric_name, p_te, s_te))
# Out:
# AVERAGE TRAINING BALANCED_ACCURACY_SCORE +- STD: 1.00 +- 0.00
# AVERAGE TEST BALANCED_ACCURACY_SCORE +- STD: 0.64 +- 0.03

# %%
# We give you this code, read it and try to understand it
data_name = [os.path.basename(file)[:-9] for file in data_list]
all_data_df = [pd.read_csv(file) for file in data_list]

print('NO SCALING')
result_noscaling = systematic_data_experiment(data_name, all_data_df, sklearn_model, sklearn_metric)
result_noscaling.style.background_gradient(cmap='Blues')
# Out:
# NO SCALING
# KNEIGHBORSCLASSIFIER
# <style  type="text/css" >
#     #T_8b28c214_46b6_11ea_aacc_0242ac110008row0_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8b28c214_46b6_11ea_aacc_0242ac110008row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8b28c214_46b6_11ea_aacc_0242ac110008row0_col2 {
#             background-color:  #75b4d8;
#             color:  #000000;
#         }    #T_8b28c214_46b6_11ea_aacc_0242ac110008row0_col3 {
#             background-color:  #4191c6;
#             color:  #000000;
#         }    #T_8b28c214_46b6_11ea_aacc_0242ac110008row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8b28c214_46b6_11ea_aacc_0242ac110008row1_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8b28c214_46b6_11ea_aacc_0242ac110008row1_col2 {
#             background-color:  #deebf7;
#             color:  #000000;
#         }    #T_8b28c214_46b6_11ea_aacc_0242ac110008row1_col3 {
#             background-color:  #85bcdc;
#             color:  #000000;
#         }    #T_8b28c214_46b6_11ea_aacc_0242ac110008row2_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8b28c214_46b6_11ea_aacc_0242ac110008row2_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8b28c214_46b6_11ea_aacc_0242ac110008row2_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8b28c214_46b6_11ea_aacc_0242ac110008row2_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8b28c214_46b6_11ea_aacc_0242ac110008row3_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8b28c214_46b6_11ea_aacc_0242ac110008row3_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8b28c214_46b6_11ea_aacc_0242ac110008row3_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8b28c214_46b6_11ea_aacc_0242ac110008row3_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }</style><table id="T_8b28c214_46b6_11ea_aacc_0242ac110008" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >perf_tr</th>        <th class="col_heading level0 col1" >std_tr</th>        <th class="col_heading level0 col2" >perf_te</th>        <th class="col_heading level0 col3" >std_te</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8b28c214_46b6_11ea_aacc_0242ac110008level0_row0" class="row_heading level0 row0" >RE</th>
#                         <td id="T_8b28c214_46b6_11ea_aacc_0242ac110008row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_8b28c214_46b6_11ea_aacc_0242ac110008row0_col1" class="data row0 col1" >0.000000</td>
#                         <td id="T_8b28c214_46b6_11ea_aacc_0242ac110008row0_col2" class="data row0 col2" >0.642204</td>
#                         <td id="T_8b28c214_46b6_11ea_aacc_0242ac110008row0_col3" class="data row0 col3" >0.030012</td>
#             </tr>
#             <tr>
#                         <th id="T_8b28c214_46b6_11ea_aacc_0242ac110008level0_row1" class="row_heading level0 row1" >RAW</th>
#                         <td id="T_8b28c214_46b6_11ea_aacc_0242ac110008row1_col0" class="data row1 col0" >1.000000</td>
#                         <td id="T_8b28c214_46b6_11ea_aacc_0242ac110008row1_col1" class="data row1 col1" >0.000000</td>
#                         <td id="T_8b28c214_46b6_11ea_aacc_0242ac110008row1_col2" class="data row1 col2" >0.571887</td>
#                         <td id="T_8b28c214_46b6_11ea_aacc_0242ac110008row1_col3" class="data row1 col3" >0.028235</td>
#             </tr>
#             <tr>
#                         <th id="T_8b28c214_46b6_11ea_aacc_0242ac110008level0_row2" class="row_heading level0 row2" >CS</th>
#                         <td id="T_8b28c214_46b6_11ea_aacc_0242ac110008row2_col0" class="data row2 col0" >1.000000</td>
#                         <td id="T_8b28c214_46b6_11ea_aacc_0242ac110008row2_col1" class="data row2 col1" >0.000000</td>
#                         <td id="T_8b28c214_46b6_11ea_aacc_0242ac110008row2_col2" class="data row2 col2" >0.546047</td>
#                         <td id="T_8b28c214_46b6_11ea_aacc_0242ac110008row2_col3" class="data row2 col3" >0.024190</td>
#             </tr>
#             <tr>
#                         <th id="T_8b28c214_46b6_11ea_aacc_0242ac110008level0_row3" class="row_heading level0 row3" >CROP</th>
#                         <td id="T_8b28c214_46b6_11ea_aacc_0242ac110008row3_col0" class="data row3 col0" >1.000000</td>
#                         <td id="T_8b28c214_46b6_11ea_aacc_0242ac110008row3_col1" class="data row3 col1" >0.000000</td>
#                         <td id="T_8b28c214_46b6_11ea_aacc_0242ac110008row3_col2" class="data row3 col2" >0.747946</td>
#                         <td id="T_8b28c214_46b6_11ea_aacc_0242ac110008row3_col3" class="data row3 col3" >0.033455</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# What do you observe by comparing the accuracy on training data and on test data?

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Compute all_scaled_data_df in a one-line formula. Imitate the code in the previous cell.</b>

# %%
all_scaled_data_df = [standardize_df(data) for data in all_data_df] # CHANGE THIS!

print('WITH SCALING')
result_scaling = systematic_data_experiment(data_name, all_scaled_data_df, sklearn_model, sklearn_metric)
result_scaling.style.background_gradient(cmap='Blues')
# Out:
#       redness  elongation  fruit
# 0   -0.432637   -0.126039    1.0
# 1    1.148003    0.449690    1.0
# 2    1.765190    0.157238    1.0
# 3   -1.302076    0.591975    1.0
# 4   -1.604870    1.109809    1.0
# ..        ...         ...    ...
# 486  1.494568    1.002116   -1.0
# 487  0.684247    1.643895   -1.0
# 488  0.188271    2.106111   -1.0
# 489  0.224988    3.117721   -1.0
# 490  0.520381    2.133680   -1.0
#
# [491 rows x 3 columns]
#             0         1         2         3         4         5         6  \
# 0    1.065869  1.406080  2.184317  1.109934  1.472861  2.354839  1.070622
# 1    0.718018  0.619190  0.784670 -0.392144 -0.584854 -0.387703  1.350141
# 2    2.109421  1.628023  0.990501  2.355077  1.839583  1.228058  2.288527
# 3   -0.634735 -0.571234 -0.059234 -1.321060 -1.359044 -1.025504 -0.426801
# 4    1.780895  1.728906  1.999069  1.445925  1.370994  1.759559  0.851000
# ..        ...       ...       ...       ...       ...       ...       ...
# 486 -1.040561 -0.732647 -1.458880 -1.044362 -0.462614 -1.386924 -1.085668
# 487 -0.576760 -0.672117 -0.367979 -0.688606 -0.829335 -0.472743 -0.746252
# 488 -1.156511  0.215656 -0.676725 -0.925777  0.270830 -0.175103 -0.945908
# 489 -1.485037 -1.479184 -1.150134 -1.360588 -1.053443 -0.749123 -1.065702
# 490 -1.716938 -1.640598 -1.870541  0.101961  0.820912  0.398918  0.651344
#
#             7         8         9  ...     14571     14572     14573  \
# 0    1.378742  2.253784  1.186914  ... -0.897176 -0.869480 -0.603908
# 1    1.318203  1.769446  1.814271  ...  0.777710  0.747897  1.191928
# 2    1.721794  1.095584  2.245579  ...  1.697977  0.893279  0.237890
# 3   -0.376876  0.169023 -0.263847  ... -0.878770 -0.942171 -0.772267
# 4    0.773356  1.221933  0.853631  ...  0.906547  1.184043  1.622180
# ..        ...       ...       ...  ...       ...       ...       ...
# 486 -0.417235 -0.757537 -0.675550  ... -1.118040 -0.215260 -1.015453
# 487 -0.841005 -0.504839 -0.126613  ...  0.004686 -0.178915  0.088237
# 488  0.329407 -0.546955 -0.753970  ... -1.081229 -0.269779 -0.865800
# 489 -0.497953 -0.441664 -0.851994  ... -0.860365 -0.814962 -0.529081
# 490  1.641076  1.179816 -0.459896  ...  0.630467  1.910954  1.004862
#
#         14574     14575     14576     14577     14578     14579  14580
# 0    0.768774  1.098645  1.155626  1.538043  2.129271  2.218734    1.0
# 1    0.298814  0.267439  0.662335  0.246987  0.378600  0.759694    1.0
# 2    1.401412  0.610763 -0.031926  0.777558  0.057048 -0.429153    1.0
# 3   -0.858009 -0.925161 -0.744457 -0.849525 -0.979063 -0.843448    1.0
# 4    1.799070  2.128618  2.507609  1.573414  1.932767  2.416875    1.0
# ..        ...       ...       ...       ...       ...       ...    ...
# 486 -1.255667 -0.527628 -1.237748 -1.680753 -1.443527 -1.672039   -1.0
# 487 -0.948386 -1.123928 -0.780997 -0.778783 -0.925471 -0.429153   -1.0
# 488 -1.020688 -0.112025 -0.525217 -1.008697 -0.353823 -0.663320   -1.0
# 489 -1.382195 -1.250416 -1.182938 -0.637297 -0.603919 -0.501204   -1.0
# 490  0.497643  1.694946  0.899846  0.512273  1.664807  0.849758   -1.0
#
# [491 rows x 14581 columns]
#             R         G         B  M=maxRGB  m=minRGB     C=M-m  R-(G+B)/2  \
# 0   -0.094697 -0.802912  1.418747 -0.891020  1.336466 -1.696950  -0.432637
# 1    0.503616 -0.772561 -0.666665  0.183203 -0.913998  0.879247   1.148003
# 2    0.061006 -1.398826 -2.104806 -0.741563 -2.119769  1.269262   1.765190
# 3   -1.726425  0.099504 -0.595447 -0.333516 -0.686620  0.349539  -1.302076
# 4   -0.060727  1.399374  1.787878  1.139418  1.806535 -0.746776  -1.604870
# ..        ...       ...       ...       ...       ...       ...        ...
# 486  2.002462  1.062099 -0.352364  1.473001 -0.273606  1.199252   1.494568
# 487  1.322292  0.595692  0.462011  0.603670  0.642721 -0.134802   0.684247
# 488  1.813416  0.972799  1.974316  1.207609  2.264663 -1.081866   0.188271
# 489  1.495356  0.452476  1.809147  0.776486  2.078160 -1.211689   0.224988
# 490  1.997458  1.183342  1.453943  1.426589  1.719892 -0.485345   0.520381
#
#           G-B  G-(R+B)/2       B-R  ...   (G-B)/C   (B-R)/C   (R-G)/C  \
# 0   -1.660362  -1.347004  1.210587  ... -2.336012  0.646130  1.179120
# 1   -0.029340  -0.573507 -0.898534  ... -0.629588 -0.462186  0.866252
# 2    0.639794  -0.241299 -1.738912  ... -0.096683 -0.983712  0.919732
# 3    0.529659   1.114701  0.760168  ...  0.582662  1.098479 -1.379813
# 4   -0.394783   0.394178  1.483473  ...  0.414910  1.919623 -1.962907
# ..        ...        ...       ...  ...       ...       ...       ...
# 486  1.019738   0.242756 -1.721703  ...  0.387062 -1.024194  0.595124
# 487  0.062782  -0.266759 -0.577431  ...  0.423864 -1.047321  0.587708
# 488 -0.839013  -0.874212  0.287837  ... -0.151124 -0.962697  0.942077
# 489 -1.077854  -1.115044  0.383211  ... -0.655381 -1.002543  1.351166
# 490 -0.289125  -0.517923 -0.263402  ...  0.234279 -1.035540  0.718445
#
#      (R+G+B)/3       C/V         W         H       W/H       W*H  fruit
# 0     0.326008 -1.650431  0.249030  0.065306 -0.126039 -0.032573    1.0
# 1    -0.499504  0.938614  0.278258 -0.273339  0.449690 -0.190080    1.0
# 2    -1.801489  1.726784  2.273420  1.076728  0.157238  1.436246    1.0
# 3    -1.107018  0.552259 -0.145793 -0.563028  0.591975 -0.426325    1.0
# 4     1.630251 -0.909639 -1.142907 -1.194313  1.109809 -0.814331    1.0
# ..         ...       ...       ...       ...       ...       ...    ...
# 486   1.300823  0.816689 -0.731192 -0.982537  1.002116 -0.694657   -1.0
# 487   1.183021 -0.327289 -0.113088 -0.876300  1.643895 -0.553957   -1.0
# 488   2.425516 -1.256659  0.159625 -0.878864  2.106111 -0.508655   -1.0
# 489   1.925434 -1.327109  0.227024 -1.040812  3.117721 -0.575667   -1.0
# 490   2.336570 -0.763992 -1.002595 -1.299831  2.133680 -0.827973   -1.0
#
# [491 rows x 22 columns]
#             0         1         2         3         4         5         6  \
# 0   -0.089163 -0.124894 -0.168847 -1.143948 -1.240265 -1.209337  0.768527
# 1    0.775519  0.450370  0.486442  0.277185 -0.058460 -0.150445  0.422443
# 2    2.034949  1.466670  0.863729  2.146071  1.604079  0.993159  2.095180
# 3    0.155203  0.412019  1.062302  0.257717  0.442305  0.993159  0.537804
# 4    1.640202  1.313266  0.923301  1.484174  1.263559  0.781381 -0.731169
# ..        ...       ...       ...       ...       ...       ...       ...
# 486 -1.386188 -0.738510 -1.102138 -1.163415 -0.378949 -0.637535 -1.058026
# 487 -0.352328 -0.220772 -0.188704 -0.793531 -0.559225 -0.552824 -1.307975
# 488 -1.480175 -0.546755 -1.221281 -1.163415  0.001632 -0.595179 -0.731169
# 489 -0.859859  0.124387  0.546014 -0.949272 -0.859684 -0.743424 -0.865757
# 490 -1.310998 -0.776860 -1.499283 -0.910337 -0.198674 -1.124626 -0.961892
#
#             7         8         9  ...      3063      3064      3065  \
# 0    0.542955  0.641150  0.738097  ... -0.015997 -0.035845  0.435083
# 1    0.384163  0.538814  1.343525  ...  0.180812  0.511872  1.222924
# 2    1.555249  0.907222  2.081390  ...  1.647929  0.913531  0.253274
# 3    0.701746  1.009558  0.302945  ... -0.499072 -0.693106 -0.675973
# 4   -0.806771 -0.730146 -1.040348  ... -1.089497 -1.167794 -1.261803
# ..        ...       ...       ...  ...       ...       ...       ...
# 486 -0.191455 -0.812015 -0.832232  ... -1.304197 -1.131279 -1.544618
# 487 -0.727376 -0.791547 -1.740374  ... -0.087564 -0.711363 -0.372958
# 488  0.582652 -0.157067 -1.343062  ... -1.017930  0.018927 -0.049741
# 489 -0.687678 -0.484541 -0.870072  ... -0.391722 -0.127131 -0.170948
# 490 -0.012815 -1.323692 -1.343062  ... -0.856905 -0.309704 -0.918386
#
#          3066      3067      3068      3069      3070      3071  3072
# 0    0.087039  0.119106  0.636189  0.679501  0.728987  1.274540   1.0
# 1    1.141156  1.327392  1.751863  0.519399  0.673445  0.977041   1.0
# 2    1.444885  0.806900  0.177966  1.106441  0.488304 -0.074122   1.0
# 3   -0.967077 -1.144947 -1.037322 -1.579719 -1.714870 -1.601284   1.0
# 4   -0.949211 -0.866112 -0.738481 -0.103220  0.155051  0.580376   1.0
# ..        ...       ...       ...       ...       ...       ...   ...
# 486 -1.681732 -1.052002 -1.754541 -1.063834 -0.178203 -0.867453  -1.0
# 487 -0.109491 -0.735989 -0.240412 -0.583527 -0.881737 -0.510454  -1.0
# 488 -0.824146  0.472297  0.337348 -1.366249 -1.029850 -1.085619  -1.0
# 489  0.176371  0.862667  0.795571 -0.281112  0.284649  0.124210  -1.0
# 490 -0.681215 -0.587277 -1.117013  0.039093  0.654930 -0.688954  -1.0
#
# [491 rows x 3073 columns]
# WITH SCALING
# KNEIGHBORSCLASSIFIER
# <style  type="text/css" >
#     #T_a9126e9c_46b6_11ea_aacc_0242ac110008row0_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_a9126e9c_46b6_11ea_aacc_0242ac110008row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_a9126e9c_46b6_11ea_aacc_0242ac110008row0_col2 {
#             background-color:  #c4daee;
#             color:  #000000;
#         }    #T_a9126e9c_46b6_11ea_aacc_0242ac110008row0_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_a9126e9c_46b6_11ea_aacc_0242ac110008row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_a9126e9c_46b6_11ea_aacc_0242ac110008row1_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_a9126e9c_46b6_11ea_aacc_0242ac110008row1_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_a9126e9c_46b6_11ea_aacc_0242ac110008row1_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_a9126e9c_46b6_11ea_aacc_0242ac110008row2_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_a9126e9c_46b6_11ea_aacc_0242ac110008row2_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_a9126e9c_46b6_11ea_aacc_0242ac110008row2_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_a9126e9c_46b6_11ea_aacc_0242ac110008row2_col3 {
#             background-color:  #e3eef8;
#             color:  #000000;
#         }    #T_a9126e9c_46b6_11ea_aacc_0242ac110008row3_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_a9126e9c_46b6_11ea_aacc_0242ac110008row3_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_a9126e9c_46b6_11ea_aacc_0242ac110008row3_col2 {
#             background-color:  #3888c1;
#             color:  #000000;
#         }    #T_a9126e9c_46b6_11ea_aacc_0242ac110008row3_col3 {
#             background-color:  #c9ddf0;
#             color:  #000000;
#         }</style><table id="T_a9126e9c_46b6_11ea_aacc_0242ac110008" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >perf_tr</th>        <th class="col_heading level0 col1" >std_tr</th>        <th class="col_heading level0 col2" >perf_te</th>        <th class="col_heading level0 col3" >std_te</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a9126e9c_46b6_11ea_aacc_0242ac110008level0_row0" class="row_heading level0 row0" >RE</th>
#                         <td id="T_a9126e9c_46b6_11ea_aacc_0242ac110008row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_a9126e9c_46b6_11ea_aacc_0242ac110008row0_col1" class="data row0 col1" >0.000000</td>
#                         <td id="T_a9126e9c_46b6_11ea_aacc_0242ac110008row0_col2" class="data row0 col2" >0.615440</td>
#                         <td id="T_a9126e9c_46b6_11ea_aacc_0242ac110008row0_col3" class="data row0 col3" >0.020409</td>
#             </tr>
#             <tr>
#                         <th id="T_a9126e9c_46b6_11ea_aacc_0242ac110008level0_row1" class="row_heading level0 row1" >RAW</th>
#                         <td id="T_a9126e9c_46b6_11ea_aacc_0242ac110008row1_col0" class="data row1 col0" >1.000000</td>
#                         <td id="T_a9126e9c_46b6_11ea_aacc_0242ac110008row1_col1" class="data row1 col1" >0.000000</td>
#                         <td id="T_a9126e9c_46b6_11ea_aacc_0242ac110008row1_col2" class="data row1 col2" >0.554434</td>
#                         <td id="T_a9126e9c_46b6_11ea_aacc_0242ac110008row1_col3" class="data row1 col3" >0.037543</td>
#             </tr>
#             <tr>
#                         <th id="T_a9126e9c_46b6_11ea_aacc_0242ac110008level0_row2" class="row_heading level0 row2" >CS</th>
#                         <td id="T_a9126e9c_46b6_11ea_aacc_0242ac110008row2_col0" class="data row2 col0" >1.000000</td>
#                         <td id="T_a9126e9c_46b6_11ea_aacc_0242ac110008row2_col1" class="data row2 col1" >0.000000</td>
#                         <td id="T_a9126e9c_46b6_11ea_aacc_0242ac110008row2_col2" class="data row2 col2" >0.792288</td>
#                         <td id="T_a9126e9c_46b6_11ea_aacc_0242ac110008row2_col3" class="data row2 col3" >0.022164</td>
#             </tr>
#             <tr>
#                         <th id="T_a9126e9c_46b6_11ea_aacc_0242ac110008level0_row3" class="row_heading level0 row3" >CROP</th>
#                         <td id="T_a9126e9c_46b6_11ea_aacc_0242ac110008row3_col0" class="data row3 col0" >1.000000</td>
#                         <td id="T_a9126e9c_46b6_11ea_aacc_0242ac110008row3_col1" class="data row3 col1" >0.000000</td>
#                         <td id="T_a9126e9c_46b6_11ea_aacc_0242ac110008row3_col2" class="data row3 col2" >0.712340</td>
#                         <td id="T_a9126e9c_46b6_11ea_aacc_0242ac110008row3_col3" class="data row3 col3" >0.024460</td>
#             </tr>
#     </tbody></table>

# %%
# This is how to collect the test results in a single dataframe
joint_results = pd.DataFrame()
joint_results['SCALED'] = result_scaling.perf_te
joint_results['NOT SCALED'] = result_noscaling.perf_te
joint_results
# Out:
#         SCALED  NOT SCALED
# RE    0.615440    0.642204
# RAW   0.554434    0.571887
# CS    0.792288    0.546047
# CROP  0.712340    0.747946

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Put here the code to plot "joint_results" as a bar graph. Check the <a href="Check https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.bar.html"> documentation</a></b>.

# %%
joint_results.plot.bar(rot=0) # REPLACE THIS!
plt.ylabel(sklearn_metric.__name__)
# Out:
# Text(0, 0.5, 'balanced_accuracy_score')

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Your final answers to question 3:</a></b> Does rescaling always help? In which case does it help most?

# %%
# Put your answer to question 3 here
rescaling_always_help = 0 # 0 for false, 1 for true
varnum_rescaling_helps_most = 0 # num of var (0-based) for which perf. improve most after rescaling
case_num_rescaling_helps_most = 2 # num of case (0-based) for which perf. improve most after rescaling

# This is the checker code, keep it
question = 3
answer = (p_tr+s_tr+p_te+s_te)/10
print(joint_results.sum().sum())
answer += joint_results.sum().sum()/10-rescaling_always_help-case_num_rescaling_helps_most
score += check(answer, question)
# Out:
# 5.182585461987417
# -1.3145198580879243
# -1.3145198580879243
# <div style="background:#00FF00">CORRECT<br>:-)</div>

# %% [markdown]
# ## Step 2: Identify the best model
# We are now ready to perform systematic experiments on various models. We will use the methods proposed in the variable `classifiers` of <a href="https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html">these scikit-learn examples</a>, compare classifier performances on the dataset `CS_SCALED`:
#
# ### Question 4: Overfitting and underfitting
#
# </b> There may be two reasons why a model performs poorly. It could either be <b>overfitting</b> or <b>underfitting</b> data.
#
# First you will perform these steps (with some help):
#
# * Create a variable `data_df` and assign to it the data frame of the scaled version of the CS dataset.
# * Create a variable `model_name` and a variable `model_list` containing the list of model names and the list of models (classifiers) from the <a href="https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html">the scikit-learn examples</a> we pointed you to.
# * Call `systematic_model_experiment(data_df, model_name, model_list, sklearn_metric)` and display the results.
# * Find which method performs best. <b>Tip:</b> Use <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.idxmax.html#pandas.Series.idxmax">idxmax</a>.
# * Find which models have TEST performance UNDER THE MEDIAN test performance. The single out models with TRAINING performance UNDER THE MEDIAN and those with TRAINING performance OVER THE MEDIAN.
#
# Then answer those questions:
# * If the test performance is bad but the training performance is good, is the model under-fitting or over-fitting?
# * If both are bad, is the model is under-fitting or over-fitting?
# * Which models are over-fitted and which ones are under-fitted?

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Choose the correct dataset: CS representation, scaled data.</b>

# %%
dataset_choice = 2 # Change that
data_df = all_scaled_data_df[dataset_choice]# Change that


print(data_df.shape)
# Out:
# (491, 22)

# %% [markdown]
# #### Classifier comparison
# We import a bunch of classifiers, inspired
# by <a href="https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html">that list</a>.

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

model_name = ["Nearest Neighbors", "Linear SVM", "RBF SVM", "Gaussian Process",
         "Decision Tree", "Random Forest", "Neural Net", "AdaBoost",
         "Naive Bayes", "QDA"]
model_list = [
    KNeighborsClassifier(3),
    SVC(kernel="linear", C=0.025),
    SVC(gamma=2, C=1),
    GaussianProcessClassifier(1.0 * RBF(1.0)),
    DecisionTreeClassifier(max_depth=10),
    RandomForestClassifier(max_depth=10, n_estimators=10, max_features=1),
    MLPClassifier(alpha=1, max_iter=1000),
    AdaBoostClassifier(),
    GaussianNB(),
    QuadraticDiscriminantAnalysis()]

# %% [markdown]
# #### Systematic experiments:
# We give you this code to make systematic experiments (run all models on the chosen representation). You may get a warning. What could explain it?

# %% [markdown]
# If an increase in X1, say, is associated with an decrease in X2and they both increase variable Y, every change in X1 will be compensated by a change in X2  and you will underestimate the effect of X1on Y.
# In LDA, you would underestimate the effect of X1 on the classification.

# %%
compar_results = systematic_model_experiment(data_df, model_name, model_list, sklearn_metric)
compar_results.round(2).style.background_gradient(cmap='Blues')
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:691: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/conda/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:691: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/conda/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:691: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/conda/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:691: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/conda/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:691: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/conda/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:691: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/conda/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:691: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/conda/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:691: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/conda/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:691: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/conda/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:691: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# <style  type="text/css" >
#     #T_e815f460_46b6_11ea_aacc_0242ac110008row0_col0 {
#             background-color:  #5da5d1;
#             color:  #000000;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row0_col1 {
#             background-color:  #3787c0;
#             color:  #000000;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row0_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row0_col3 {
#             background-color:  #3787c0;
#             color:  #000000;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row1_col1 {
#             background-color:  #abd0e6;
#             color:  #000000;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row1_col2 {
#             background-color:  #2373b6;
#             color:  #f1f1f1;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row1_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row2_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row2_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row2_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row2_col3 {
#             background-color:  #abd0e6;
#             color:  #000000;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row3_col0 {
#             background-color:  #9fcae1;
#             color:  #000000;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row3_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row3_col2 {
#             background-color:  #083b7c;
#             color:  #f1f1f1;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row3_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row4_col0 {
#             background-color:  #083a7a;
#             color:  #f1f1f1;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row4_col1 {
#             background-color:  #3787c0;
#             color:  #000000;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row4_col2 {
#             background-color:  #2373b6;
#             color:  #f1f1f1;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row4_col3 {
#             background-color:  #3787c0;
#             color:  #000000;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row5_col0 {
#             background-color:  #08468b;
#             color:  #f1f1f1;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row5_col1 {
#             background-color:  #abd0e6;
#             color:  #000000;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row5_col2 {
#             background-color:  #08478d;
#             color:  #f1f1f1;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row5_col3 {
#             background-color:  #abd0e6;
#             color:  #000000;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row6_col0 {
#             background-color:  #9fcae1;
#             color:  #000000;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row6_col1 {
#             background-color:  #3787c0;
#             color:  #000000;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row6_col2 {
#             background-color:  #083b7c;
#             color:  #f1f1f1;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row6_col3 {
#             background-color:  #abd0e6;
#             color:  #000000;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row7_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row7_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row7_col2 {
#             background-color:  #09529d;
#             color:  #f1f1f1;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row7_col3 {
#             background-color:  #abd0e6;
#             color:  #000000;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row8_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row8_col1 {
#             background-color:  #3787c0;
#             color:  #000000;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row8_col2 {
#             background-color:  #2373b6;
#             color:  #f1f1f1;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row8_col3 {
#             background-color:  #abd0e6;
#             color:  #000000;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row9_col0 {
#             background-color:  #abd0e6;
#             color:  #000000;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row9_col1 {
#             background-color:  #3787c0;
#             color:  #000000;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row9_col2 {
#             background-color:  #125da6;
#             color:  #f1f1f1;
#         }    #T_e815f460_46b6_11ea_aacc_0242ac110008row9_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }</style><table id="T_e815f460_46b6_11ea_aacc_0242ac110008" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >perf_tr</th>        <th class="col_heading level0 col1" >std_tr</th>        <th class="col_heading level0 col2" >perf_te</th>        <th class="col_heading level0 col3" >std_te</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e815f460_46b6_11ea_aacc_0242ac110008level0_row0" class="row_heading level0 row0" >Nearest Neighbors</th>
#                         <td id="T_e815f460_46b6_11ea_aacc_0242ac110008row0_col0" class="data row0 col0" >0.890000</td>
#                         <td id="T_e815f460_46b6_11ea_aacc_0242ac110008row0_col1" class="data row0 col1" >0.020000</td>
#                         <td id="T_e815f460_46b6_11ea_aacc_0242ac110008row0_col2" class="data row0 col2" >0.810000</td>
#                         <td id="T_e815f460_46b6_11ea_aacc_0242ac110008row0_col3" class="data row0 col3" >0.030000</td>
#             </tr>
#             <tr>
#                         <th id="T_e815f460_46b6_11ea_aacc_0242ac110008level0_row1" class="row_heading level0 row1" >Linear SVM</th>
#                         <td id="T_e815f460_46b6_11ea_aacc_0242ac110008row1_col0" class="data row1 col0" >0.760000</td>
#                         <td id="T_e815f460_46b6_11ea_aacc_0242ac110008row1_col1" class="data row1 col1" >0.010000</td>
#                         <td id="T_e815f460_46b6_11ea_aacc_0242ac110008row1_col2" class="data row1 col2" >0.750000</td>
#                         <td id="T_e815f460_46b6_11ea_aacc_0242ac110008row1_col3" class="data row1 col3" >0.010000</td>
#             </tr>
#             <tr>
#                         <th id="T_e815f460_46b6_11ea_aacc_0242ac110008level0_row2" class="row_heading level0 row2" >RBF SVM</th>
#                         <td id="T_e815f460_46b6_11ea_aacc_0242ac110008row2_col0" class="data row2 col0" >1.000000</td>
#                         <td id="T_e815f460_46b6_11ea_aacc_0242ac110008row2_col1" class="data row2 col1" >0.000000</td>
#                         <td id="T_e815f460_46b6_11ea_aacc_0242ac110008row2_col2" class="data row2 col2" >0.580000</td>
#                         <td id="T_e815f460_46b6_11ea_aacc_0242ac110008row2_col3" class="data row2 col3" >0.020000</td>
#             </tr>
#             <tr>
#                         <th id="T_e815f460_46b6_11ea_aacc_0242ac110008level0_row3" class="row_heading level0 row3" >Gaussian Process</th>
#                         <td id="T_e815f460_46b6_11ea_aacc_0242ac110008row3_col0" class="data row3 col0" >0.850000</td>
#                         <td id="T_e815f460_46b6_11ea_aacc_0242ac110008row3_col

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Find the method performing best on test data.</b>

# %%
# Find the method performing best on test data
best_method = compar_results.perf_te.idxmax() # REPLACE THIS; try not to just do this by hand, apply idxmax to the series perf_te
print("Best method: {}".format(best_method))
# Out:
# Best method: Nearest Neighbors

# %% [markdown]
# #### Over-fitting and under-fitting
# There may be two reasons why a model performs poorly. It could either be <b>over-fitting</b> or <b>under-fitting</b> data. Under-fitting means that the model is not powerful enough to even learn the training data while over-fitting means that the model is so powerful that it can learn super-well the training data, but it might not generalize well to new test data.
#
# Of the models performing poorly (having TEST performance UNDER THE MEDIAN test performance), we highlight:
# * models with TRAINING performance UNDER THE MEDIAN training performance (<b>under-fitted</b>)
# * models with TRAINING performance OVER THE MEDIAN (<b>over-fitted</b>)

# %%
# We give you this code, check it in utilities.py of use ??analyze_model_experiments
analyze_model_experiments(compar_results)
# Out:
# <style  type="text/css" >
#     #T_4f4a0040_46b7_11ea_aacc_0242ac110008row0_col0 {
#             background-color:  yellow;
#         }    #T_4f4a0040_46b7_11ea_aacc_0242ac110008row0_col1 {
#             background-color:  yellow;
#         }    #T_4f4a0040_46b7_11ea_aacc_0242ac110008row0_col2 {
#             background-color:  yellow;
#         }    #T_4f4a0040_46b7_11ea_aacc_0242ac110008row0_col3 {
#             background-color:  yellow;
#         }    #T_4f4a0040_46b7_11ea_aacc_0242ac110008row1_col5 {
#             background-color:  yellow;
#         }    #T_4f4a0040_46b7_11ea_aacc_0242ac110008row2_col0 {
#             background-color:  yellow;
#         }    #T_4f4a0040_46b7_11ea_aacc_0242ac110008row2_col4 {
#             background-color:  yellow;
#         }    #T_4f4a0040_46b7_11ea_aacc_0242ac110008row3_col1 {
#             background-color:  yellow;
#         }    #T_4f4a0040_46b7_11ea_aacc_0242ac110008row3_col2 {
#             background-color:  yellow;
#         }    #T_4f4a0040_46b7_11ea_aacc_0242ac110008row4_col0 {
#             background-color:  yellow;
#         }    #T_4f4a0040_46b7_11ea_aacc_0242ac110008row4_col3 {
#             background-color:  yellow;
#         }    #T_4f4a0040_46b7_11ea_aacc_0242ac110008row4_col4 {
#             background-color:  yellow;
#         }    #T_4f4a0040_46b7_11ea_aacc_0242ac110008row5_col0 {
#             background-color:  yellow;
#         }    #T_4f4a0040_46b7_11ea_aacc_0242ac110008row5_col2 {
#             background-color:  yellow;
#         }    #T_4f4a0040_46b7_11ea_aacc_0242ac110008row6_col1 {
#             background-color:  yellow;
#         }    #T_4f4a0040_46b7_11ea_aacc_0242ac110008row6_col2 {
#             background-color:  yellow;
#         }    #T_4f4a0040_46b7_11ea_aacc_0242ac110008row7_col0 {
#             background-color:  yellow;
#         }    #T_4f4a0040_46b7_11ea_aacc_0242ac110008row7_col2 {
#             background-color:  yellow;
#         }    #T_4f4a0040_46b7_11ea_aacc_0242ac110008row7_col3 {
#             background-color:  yellow;
#         }    #T_4f4a0040_46b7_11ea_aacc_0242ac110008row8_col1 {
#             background-color:  yellow;
#         }    #T_4f4a0040_46b7_11ea_aacc_0242ac110008row8_col3 {
#             background-color:  yellow;
#         }    #T_4f4a0040_46b7_11ea_aacc_0242ac110008row8_col5 {
#             background-color:  yellow;
#         }    #T_4f4a0040_46b7_11ea_aacc_0242ac110008row9_col1 {
#             background-color:  yellow;
#         }    #T_4f4a0040_46b7_11ea_aacc_0242ac110008row9_col3 {
#             background-color:  yellow;
#         }    #T_4f4a0040_46b7_11ea_aacc_0242ac110008row9_col5 {
#             background-color:  yellow;
#         }</style><table id="T_4f4a0040_46b7_11ea_aacc_0242ac110008" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >perf_tr</th>        <th class="col_heading level0 col1" >std_tr</th>        <th class="col_heading level0 col2" >perf_te</th>        <th class="col_heading level0 col3" >std_te</th>        <th class="col_heading level0 col4" >Overfitted</th>        <th class="col_heading level0 col5" >Underfitted</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4f4a0040_46b7_11ea_aacc_0242ac110008level0_row0" class="row_heading level0 row0" >Nearest Neighbors</th>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row0_col0" class="data row0 col0" >0.890110</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row0_col1" class="data row0 col1" >0.018133</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row0_col2" class="data row0 col2" >0.814818</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row0_col3" class="data row0 col3" >0.025394</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row0_col4" class="data row0 col4" >False</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row0_col5" class="data row0 col5" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4f4a0040_46b7_11ea_aacc_0242ac110008level0_row1" class="row_heading level0 row1" >Linear SVM</th>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row1_col0" class="data row1 col0" >0.760862</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row1_col1" class="data row1 col1" >0.012747</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row1_col2" class="data row1 col2" >0.748730</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row1_col3" class="data row1 col3" >0.013419</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row1_col4" class="data row1 col4" >False</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row1_col5" class="data row1 col5" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_4f4a0040_46b7_11ea_aacc_0242ac110008level0_row2" class="row_heading level0 row2" >RBF SVM</th>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row2_col0" class="data row2 col0" >0.999367</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row2_col1" class="data row2 col1" >0.001899</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row2_col2" class="data row2 col2" >0.579652</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row2_col3" class="data row2 col3" >0.019193</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row2_col4" class="data row2 col4" >True</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row2_col5" class="data row2 col5" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4f4a0040_46b7_11ea_aacc_0242ac110008level0_row3" class="row_heading level0 row3" >Gaussian Process</th>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row3_col0" class="data row3 col0" >0.850530</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row3_col1" class="data row3 col1" >0.032395</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row3_col2" class="data row3 col2" >0.796938</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row3_col3" class="data row3 col3" >0.011843</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row3_col4" class="data row3 col4" >False</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row3_col5" class="data row3 col5" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4f4a0040_46b7_11ea_aacc_0242ac110008level0_row4" class="row_heading level0 row4" >Decision Tree</th>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row4_col0" class="data row4 col0" >0.988097</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row4_col1" class="data row4 col1" >0.017095</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row4_col2" class="data row4 col2" >0.747370</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row4_col3" class="data row4 col3" >0.031497</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row4_col4" class="data row4 col4" >True</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row4_col5" class="data row4 col5" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4f4a0040_46b7_11ea_aacc_0242ac110008level0_row5" class="row_heading level0 row5" >Random Forest</th>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row5_col0" class="data row5 col0" >0.979899</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row5_col1" class="data row5 col1" >0.014624</td>
#                         <td id="T_4f4a0040_46b7_11ea_aacc_0242ac110008row5_col2" class="data row5 col2" >0.786341</td>

# %% [markdown]
# #### Bar graph comparing  results

# %%
compar_results[['perf_tr', 'perf_te']].plot.bar()
plt.ylim(0.5, 1)
plt.ylabel(sklearn_metric.__name__)
# Out:
# Text(0, 0.5, 'balanced_accuracy_score')

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>
# <b>Your final answers to question 4:</a> </b>Which methods overfits or underfit?</b>

# %%
# Put your answer to question 4 here
#If the test performance is bad but the training performance is good, is the model under-fitting or over-fitting?
answer1 = 1 # 0 for under-fitting and 1 for over-fitting
#If both are bad, is the model is under-fitting or over-fitting? 
answer2 = 0 # 0 for under-fitting and 1 for over-fitting
# Which models are over-fitted and which ones are under-fitted?
overfitted_list = [2,4,5] # Replace by the correct numbers in model_name
underfitted_list = [1,8] # Replace by the correct numbers in model_name


model_name = ["Nearest Neighbors", "Linear SVM", "RBF SVM", "Gaussian Process",
         "Decision Tree", "Random Forest", "Neural Net", "AdaBoost",
         "Naive Bayes", "QDA"]

print("Over_fitted models:")
print([model_name[i] for i in overfitted_list])
print("Under_fitted models:")
print([model_name[i] for i in underfitted_list])
# This is the checker code, keep it
question = 4
answer = answer1-answer2+sum(overfitted_list)-sum(underfitted_list)+model_name.index(best_method)

score += check(answer, question)
# Out:
# Over_fitted models:
# ['RBF SVM', 'Decision Tree', 'Random Forest']
# Under_fitted models:
# ['Linear SVM', 'Naive Bayes']
# 3
# 3
# <div style="background:#00FF00">CORRECT<br>:-)</div>

# %% [markdown]
# ###  Question 5: Dimensionality reduction
# It is useful to reduce the data dimension (number of features) for two reasons: ease of visualisation and possibly increase in performance. Two approaches are possible:
# 1. Feature selection.
# 1. Feature transforms.
#
# In the first case, one tries to select among the original features. In the second case, one first replaces the original features by "combinations" of features, then perform selection. Here we give two simple examples: Feature ranking with the <b>Pearson correlation</b> coefficient (as a feature selection method), and <b>Singular Value Decomposition</b> or SVD (as a feature transform method) .
#
# In this section, we keep using the <b>CS scaled data</b>. We use as classifier the <b>3-nearest-neighbor</b> model, which seems to have served us well! We begin by showing you how to do simple feature selection, then we'll guide you step-by-step through SVD.

# %% [markdown]
# ### Feature selection example
# We perform feature selection with the Pearson correlation coefficient as follows:
# * Compute the correlation matrix (we will only use the last column, i.e. correlation of features with the class label to be predicted)
# * Sort the correlation coefficients (of features and class label)

# %% [markdown]
# #### Correlation matrix
# If we did things right, `data_df` should contain the CS data.

# %%
corr = data_df.corr()
corr.round(1).style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_5adfc188_46b7_11ea_aacc_0242ac110008row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row0_col1 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row0_col2 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row0_col3 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row0_col4 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row0_col5 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row0_col6 {
#             background-color:  #e57058;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row0_col7 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row0_col8 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row0_col9 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row0_col10 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row0_col11 {
#             background-color:  #f18d6f;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row0_col12 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row0_col13 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row0_col14 {
#             background-color:  #f18d6f;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row0_col15 {
#             background-color:  #e97a5f;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row0_col16 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row0_col17 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row0_col18 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row0_col19 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row0_col20 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row0_col21 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row1_col0 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row1_col2 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row1_col3 {
#             background-color:  #dc5d4a;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row1_col4 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row1_col5 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row1_col6 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row1_col7 {
#             background-color:  #ef886b;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row1_col8 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row1_col9 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row1_col10 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row1_col11 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row1_col12 {
#             background-color:  #f49a7b;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row1_col13 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row1_col14 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row1_col15 {
#             background-color:  #e97a5f;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row1_col16 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row1_col17 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row1_col18 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row1_col19 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row1_col20 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row1_col21 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row2_col0 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row2_col1 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row2_col3 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row2_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row2_col5 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row2_col6 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row2_col7 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row2_col8 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row2_col9 {
#             background-color:  #e57058;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row2_col10 {
#             background-color:  #d75445;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row2_col11 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row2_col12 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row2_col13 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row2_col14 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_5adfc188_46b7_11ea_aacc_0242ac110008row2_col15 {
#             background-color:  #e97a5f;

# %% [markdown]
# #### Sort features

# %% [markdown]
# Let us first sort all features by the <b>absolute value</b> of the Pearson correlation coefficient. Indeed, variables are informative no matter whether they are correlated or anti-correlated (since it suffices to multiply them by -1 to change the correlation direction).

# %%
sval = corr['fruit'][:-1].abs().sort_values(ascending=False)
ranked_columns = sval.index.values
print(ranked_columns)
# Out:
# ['R' '(B-R)/C' 'R-(G+B)/2' 'B-R' 'W/H' '(R+G+B)/3' 'R-G' 'B-(G+R)/2'
#  '(R-G)/C' 'M=maxRGB' '(G-B)/C' 'G' 'H' 'G-B' 'W' 'G-(R+B)/2' 'W*H'
#  'C=M-m' 'm=minRGB' 'C/V' 'B']

# %% [markdown]
# We notice that the features that we have constructed in the previous lessons 'R-(G+B)/2' and 'W/H' come in the 5 top most informative features. But there are others. Let us make all scatter plots of pairs of features for the 5 top ranked features.

# %% [markdown]
# #### Visualize top 5 features with PAIRPLOT

# %%
# Make a dataframe with only top five features
fruit_name = ['Banana', 'Apple']
fruit_list = [fruit_name[int((i+1)/2)] for i in data_df["fruit"].tolist()]
col_selected = ranked_columns[0:5]
df_5feat = pd.DataFrame.copy(data_df)
df_5feat = df_5feat[col_selected]
df_5feat['fruit'] = fruit_list
df_5feat.head()
# Out:
#           R   (B-R)/C  R-(G+B)/2       B-R       W/H  fruit
# 0 -0.094697  0.646130  -0.432637  1.210587 -0.126039  Apple
# 1  0.503616 -0.462186   1.148003 -0.898534  0.449690  Apple
# 2  0.061006 -0.983712   1.765190 -1.738912  0.157238  Apple
# 3 -1.726425  1.098479  -1.302076  0.760168  0.591975  Apple
# 4 -0.060727  1.919623  -1.604870  1.483473  1.109809  Apple

# %%
# Show pairplot
g = sns.pairplot(df_5feat, hue="fruit", markers=["o", "s"], diag_kind="hist")

# %% [markdown]
# #### Learning curves
# We want to eveluate the effect of varying the number of features. To that end, we build learning curves = performance as a function of feature number.

# %%
# We use the 3 nearest neighbor classifier to create the learnign curve
sklearn_model = KNeighborsClassifier(n_neighbors=3)
feat_lc_df = feature_learning_curve(data_df, sklearn_model, sklearn_metric)
# Out:
# KNEIGHBORSCLASSIFIER
# ['R' '(B-R)/C' 'R-(G+B)/2' 'B-R' 'W/H' '(R+G+B)/3' 'R-G' 'B-(G+R)/2'
#  '(R-G)/C' 'M=maxRGB' '(G-B)/C' 'G' 'H' 'G-B' 'W' 'G-(R+B)/2' 'W*H'
#  'C=M-m' 'm=minRGB' 'C/V' 'B']

# %%
# Plot the learning curve
plt.errorbar(feat_lc_df.index+1, feat_lc_df['perf_tr'], yerr=feat_lc_df['std_tr'], label='Training set')
plt.errorbar(feat_lc_df.index+1, feat_lc_df['perf_te'], yerr=feat_lc_df['std_te'], label='Test set')
plt.xticks(np.arange(1, 22, 1)) 
plt.xlabel('Number of features')
plt.ylabel(sklearn_metric.__name__)
plt.legend(loc='lower right')

# %% [markdown]
# We see the, with 5 features, it is about as good as it gets, given the error bars.

# %% [markdown]
# ### Singular Value Decomposition
# Let us move now to the second way of reducing dimensionality: feature transforms.
# When we use SVD, the feature transform consists in finding the "principal directions"(directions of largest variance). The method is also known as Pricipal Component Analysis (PCA). I simply used my search engine and typed the keywords "pandas svd". I found a nice tutorial on <a href="https://machinelearningmastery.com/singular-value-decomposition-for-machine-learning/">this page</a> and a step-by-step procedure on <a href="https://cmdlinetips.com/2019/05/singular-value-decomposition-svd-in-python/">this page</a>.
#
# We will guide you step-by-step:
# * Create a dataframe called `df_scaled` containing the standardized columns, except the last one (tip: just use `drop` to eliminate the last column).
# * Perform a singular value decomposition of `df_scaled` and call the resulting matrices u, s, v.
# * Make a scree plot of the eigen values (square of the singular values). Save the plot in file 'svd_scree_plot.png'.
# * Create a new dataframe `svd_df` with the two singular values as columns and the fruit type as index.
# * Make pairwise scatter plots of the three first singular values.
#
# Then the question to answer will be to compute the performances obtained with the 3 nearest neighbor method using the first 3 singular values.

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>

# %%
# Make use the CS scaled dataset (this should be already loaded in data_df,
# if you did things correctly in previous questions)
# To obtain df_scaled, remove the last column of data_df.

df_scaled = data_df.drop(columns=['fruit']) # REPLACE THIS BY THE CORRECT ANSWER

df_scaled.head()
# Out:
#           R         G         B  M=maxRGB  m=minRGB     C=M-m  R-(G+B)/2  \
# 0 -0.094697 -0.802912  1.418747 -0.891020  1.336466 -1.696950  -0.432637
# 1  0.503616 -0.772561 -0.666665  0.183203 -0.913998  0.879247   1.148003
# 2  0.061006 -1.398826 -2.104806 -0.741563 -2.119769  1.269262   1.765190
# 3 -1.726425  0.099504 -0.595447 -0.333516 -0.686620  0.349539  -1.302076
# 4 -0.060727  1.399374  1.787878  1.139418  1.806535 -0.746776  -1.604870
#
#         G-B  G-(R+B)/2       B-R  ...       R-G   (G-B)/C   (B-R)/C   (R-G)/C  \
# 0 -1.660362  -1.347004  1.210587  ...  0.579199 -2.336012  0.646130  1.179120
# 1 -0.029340  -0.573507 -0.898534  ...  1.031343 -0.629588 -0.462186  0.866252
# 2  0.639794  -0.241299 -1.738912  ...  1.189200 -0.096683 -0.983712  0.919732
# 3  0.529659   1.114701  0.760168  ... -1.457199  0.582662  1.098479 -1.379813
# 4 -0.394783   0.394178  1.483473  ... -1.189423  0.414910  1.919623 -1.962907
#
#    (R+G+B)/3       C/V         W         H       W/H       W*H
# 0   0.326008 -1.650431  0.249030  0.065306 -0.126039 -0.032573
# 1  -0.499504  0.938614  0.278258 -0.273339  0.449690 -0.190080
# 2  -1.801489  1.726784  2.273420  1.076728  0.157238  1.436246
# 3  -1.107018  0.552259 -0.145793 -0.563028  0.591975 -0.426325
# 4   1.630251 -0.909639 -1.142907 -1.194313  1.109809 -0.814331
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Perform singular value decomposition

# %%
u, s, v = np.linalg.svd(df_scaled, full_matrices=True)
print('U {}'.format(u.shape))
print('S {}'.format(s.shape))
print('V {}'.format(v.shape))
# Out:
# U (491, 491)
# S (21,)
# V (21, 21)

# %% [markdown]
# #### Make a scree plot
# This plot allows us to decide how many components to keep, considering the total variance explained.

# %%
var_explained = np.round(s**2/np.sum(s**2), decimals=3)
sns.barplot(x=list(range(1,len(var_explained)+1)),
            y=var_explained, color="limegreen")
plt.xlabel('SVs', fontsize=16)
plt.ylabel('Percent Variance Explained', fontsize=16)
plt.savefig('svd_scree_plot.png',dpi=100)

# %% [markdown]
# We see that after 3 features there is a big drop in variance. So tentatively, let us keep the top three components.

# %% [markdown]
# #### Pairplot

# %%
# Create a dataframe with only the three first principal components
fruit_name = ['Banana', 'Apple']
fruit_list = [fruit_name[int((i+1)/2)] for i in df["fruit"].tolist()]
fnum=3
labels= ['SV'+str(i) for i in range(1,fnum+1)]
df_3svd = pd.DataFrame(u[:,0:fnum], columns=labels)
df_3svd['fruit'] = fruit_list
df_3svd.head()
# Out:
#         SV1       SV2       SV3  fruit
# 0 -0.082698  0.020103  0.011550  Apple
# 1  0.022860  0.032317  0.033502  Apple
# 2  0.063949  0.088905 -0.001070  Apple
# 3  0.011986 -0.031958 -0.060016  Apple
# 4 -0.045156 -0.092459 -0.008405  Apple

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>

# %%
# Show the pairplot of svd_df
p = sns.pairplot(df_3svd, hue="fruit", markers=["o", "s"], diag_kind="hist")

# %% [markdown]
# #### Evaluate df_3svd:
# This piece of code will serve you later to answer question 5!

# %%
# We use the function df_cross_validate that we already used in question 3 to evaluate svd_df
df_3svd['fruit'] = df.iloc[:, -1].to_numpy() # We replace the target values by numbers
p_tr, s_tr, p_te, s_te = df_cross_validate(df_3svd, sklearn_model, sklearn_metric)
metric_name = sklearn_metric.__name__.upper()
print("AVERAGE TRAINING {0:s} +- STD: {1:.2f} +- {2:.2f}".format(metric_name, p_tr, s_tr))
print("AVERAGE TEST {0:s} +- STD: {1:.2f} +- {2:.2f}".format(metric_name, p_te, s_te))
# Out:
# AVERAGE TRAINING BALANCED_ACCURACY_SCORE +- STD: 0.86 +- 0.02
# AVERAGE TEST BALANCED_ACCURACY_SCORE +- STD: 0.76 +- 0.02

# %% [markdown]
# #### SVD learning curve:

# %%
# We compute the learning curve for the 3-nearest neighbor classifier ...
sklearn_model = KNeighborsClassifier(n_neighbors=3)
feat_lc_df = svd_learning_curve(data_df, sklearn_model, sklearn_metric)

# and we plot the learning curve
plt.errorbar(feat_lc_df.index+1, feat_lc_df['perf_tr'], yerr=feat_lc_df['std_tr'], label='Training set')
plt.errorbar(feat_lc_df.index+1, feat_lc_df['perf_te'], yerr=feat_lc_df['std_te'], label='Test set')
plt.xticks(np.arange(1, 22, 1)) 
plt.xlabel('Number of principal compoments')
plt.ylabel(sklearn_metric.__name__)
plt.legend(loc='lower right')
# Out:
# KNEIGHBORSCLASSIFIER

# %% [markdown]
# #### Comparison of dimensionality reduction methods

# %% [markdown]
# Even though features 4 and 5 did not seem to explain a lot of additional variance, there seems to be an optimum at 4 or 5 features. Compare the performances of df_5feat and df_5svd (with 5 top components). Is one significantly better then the other?

# %% [markdown]
# <div style="background:#FFFFAA">
#     Here you need to do something!
# </div>

# %%
df_5svd = df_3svd # Replace with the correct dataframe having 5 principal components

# Put here the code to compute the performances of df_5feat and df_5svd
fnum=5
labels= ['SV'+str(i) for i in range(1,fnum+1)]
df_5svd = pd.DataFrame(u[:,0:fnum], columns=labels)
df_5svd['fruit'] = df.iloc[:, -1].to_numpy() # Need numeric values
p_tr_5svd, s_tr_5svd, p_te_5svd, s_te_5svd = df_cross_validate(df_5svd, sklearn_model, sklearn_metric) # REPLACE THIS
p_tr_5feat, s_tr_5feat, p_te_5feat, s_te_5feat = df_cross_validate(df_5feat, sklearn_model, sklearn_metric)
 # REPLACE THIS

print("5FEAT AVERAGE TRAINING {0:s} +- STD: {1:.2f} +- {2:.2f}".format(metric_name, p_tr_5feat, s_tr_5feat))
print("5FEAT AVERAGE TEST {0:s} +- STD: {1:.2f} +- {2:.2f}".format(metric_name, p_te_5feat, s_te_5feat))
print("5SVD AVERAGE TRAINING {0:s} +- STD: {1:.2f} +- {2:.2f}".format(metric_name, p_tr_5svd, s_tr_5svd))
print("5SVD AVERAGE TEST {0:s} +- STD: {1:.2f} +- {2:.2f}".format(metric_name, p_te_5svd, s_te_5svd))
# Out:
# 5FEAT AVERAGE TRAINING BALANCED_ACCURACY_SCORE +- STD: 0.89 +- 0.02
# 5FEAT AVERAGE TEST BALANCED_ACCURACY_SCORE +- STD: 0.81 +- 0.03
# 5SVD AVERAGE TRAINING BALANCED_ACCURACY_SCORE +- STD: 0.91 +- 0.02
# 5SVD AVERAGE TEST BALANCED_ACCURACY_SCORE +- STD: 0.82 +- 0.02

# %%
#Does one method give significantly better results than the other?
answer = -1 # One for yes and 0 for no

# This is the checker code, keep it
question = 5
answer = 0.001*(p_te_5feat-p_te_5svd)/(s_te_5feat+s_te_5svd)
score += check(answer, question)
# Out:
# -0.0001927453473634895
# -0.0001927453473634895
# <div style="background:#00FF00">CORRECT<br>:-)</div>

# %%
print('Your final score is %d / 5, congratulations!' % score)
# Out:
# Your final score is 5 / 5, congratulations!

# %% [markdown]
# <div style="background:#FFFFAA">
# <span style="color:red">
# <br>
#     To finalize your homework:
# <b>
# <ul>
#     <li> Use  Kernel + Restart and Run all.</li>
#     <li> Save your notebook.</li>
#     <li> Push your changes to your GitHub repo with:</li>
# </ul>
# </b>
# <pre>
# git add .
# git commit -m 'my homework is done'
# git push
# </pre>
# <br>
# </span>
# </div>
